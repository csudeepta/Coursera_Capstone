# %% [markdown]
# <h1>Capstone Project - The Battle of the Neighborhoods</h1>

# %% [markdown]
# <h2>Problem Description and Background</h2>
# In a globally connected world there is a huge influx of people from all over the world into economic hubs of the worlds. Chicago is the third largest city of the US by population and a hotbed for global migrant seeking employment.
#
# While big cities provide enormous opportunities for the job seeker and the migrant, it also harbours crimes. A person wanting to come over to a city will surely look at the safety aspect of the various neighbourhoods in a city before deciding. The objective of this project is to analyse the available crime statistics for a particular year for the city of Chicago and try to highlight the safety of neightbourhoods relative to each other.

# %% [markdown]
# <h1>Data Description</h1>
#
# We basically need two sets of data. One that provides us the data for the crimes per neighborhoods of Chicago and the other detailing the District Names and district codes of Chicago. The data is extracted from these sources:
# 1. Crime Data : https://data.cityofchicago.org/api/views/vwwp-7yr9/rows.csv?accessType=DOWNLOAD
# 2. District Information: https://en.wikipedia.org/wiki/Community_areas_in_Chicago

# %% [markdown]
# <h1>Methodology</h1>
# The following steps are required to fetch the data and parse and merge
#
# * Fetch the crime data for Chicago for a year (2015).
# * Parse the data for rows and columns that are meaningful for the analysis
# * Use the BeautifulSoup library -
#   * Scrapping the source URL for extracting district names and neighbourhood.
# * Create panda dataframe for the District names and neighdourhoods
# * Filter the crime data for very specific crime categories
#   * We have filtered only the following categories of crimes:
#     * ARSON
#     * ASSAULT
#     * BATTERY
#     * BURGLARY
#     * TRESPASS
#     * SEX OFFENSE
# * Pivot the crime data for summary results for each district
#   * Summary is on percentage of major crimes of the total crimes reported
# * Merge the district crime results with the district names and neighbourhood dataframe
# * Sort the report by crime % to get a list of least crime infested neighbouroods.
#
# Once we have created the final data frame, sorted in escending order of the major crimes as a percentage of total crime we get an overall picture of the safest localities of the City of Chicago. This helps a prospective home seeker to rate a neighbourhood's safety relative to the other neighbourhoods.

# %% [markdown]
# <h3>Import the libraries</h3>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>Fetch the crime data for the year 2015</h3>

# %%
crime2015_df = pd.read_csv('https://data.cityofchicago.org/api/views/vwwp-7yr9/rows.csv?accessType=DOWNLOAD')
crime2015_df = crime2015_df[crime2015_df['Latitude'].notna()]
crime2015_df = crime2015_df[crime2015_df['Longitude'].notna()]
crime2015_df.shape
# Out:
# (257893, 22)

# %% [markdown]
# <h3>Drop the columns that are not important</h3>

# %%
crime2015_df = crime2015_df[['ID', 'Case Number', 'Block', 'Primary Type', 'Location Description', 
                             'Arrest', 'District', 'Ward', 'Latitude', 'Longitude']]
crime2015_df.shape
# Out:
# (257893, 10)

# %%
crime2015_df.head()
# Out:
#           ID Case Number                  Block                Primary Type  \
# 3   10310586    HY499294   044XX W DIVERSEY AVE                     BATTERY
# 8   10004094    HY193838  035XX W FULLERTON AVE                     BATTERY
# 11  10224250    HY410830    060XX S RICHMOND ST                     BATTERY
# 13  10361286    HY552885     023XX N SAWYER AVE         CRIM SEXUAL ASSAULT
# 15  10326578    HY517169     073XX S KEDZIE AVE  OFFENSE INVOLVING CHILDREN
#
#    Location Description  Arrest  District  Ward   Latitude  Longitude
# 3              SIDEWALK   False        25  31.0  41.931638 -87.738583
# 8              SIDEWALK   False        14  35.0  41.924629 -87.714759
# 11                ALLEY    True         8  16.0  41.783865 -87.697183
# 13            APARTMENT   False        14  32.0  41.923971 -87.709136
# 15            APARTMENT    True         8  18.0  41.760184 -87.702505

# %%
crime2015_df['District'].value_counts()
# Out:
# 11    18631
# 8     16936
# 6     15767
# 4     15556
# 7     15074
# 25    14747
# 3     12783
# 9     12410
# 12    12052
# 1     11762
# 10    11523
# 15    11467
# 19    11327
# 5     11153
# 18    11131
# 2     10485
# 16     9114
# 14     8774
# 22     8576
# 17     7576
# 24     6873
# 20     4167
# 31        9
# Name: District, dtype: int64

# %% [markdown]
# <h3>Use Beautiful Soup to extract District names and neighbourhoods</h3>

# %%
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
import urllib.request
url = "https://en.wikipedia.org/wiki/Community_areas_in_Chicago"
page = urllib.request.urlopen(url)

# parse the HTML page
soup = BeautifulSoup(page, "lxml")

htmlContent = soup.prettify()

DistCode      = []
Community       = []
Neighbourhood = []
for items in soup.find_all('table', {"class": "wikitable"}):

    skipped = 0
    counter = 0
    # Extract individual rows and populate the lists
    for cell in items.find_all('td'):
        if (counter == 0):
            DistCode.append(cell.text.strip())
        if (counter == 1):
            Community.append(cell.text.strip())
        if (counter == 2):
            Neighbourhood.append(cell.text.strip().replace('\n', ' ,'))
            counter = 0
        else:
            counter += 1;

# Create the directory of districts and neighbourhoods
chicagoDistricts = {'DistCode':DistCode, 'Community':Community, 'Neighbourhood':Neighbourhood}
df_chicagoDistricts = pd.DataFrame.from_dict(chicagoDistricts)
df_chicagoDistricts.head(20)
# Out:
#    DistCode        Community  \
# 0        08  Near North Side
# 1        32             Loop
# 2        33  Near South Side
# 3        05     North Center
# 4        06        Lake View
# 5        07     Lincoln Park
# 6        21         Avondale
# 7        22     Logan Square
# 8        01      Rogers Park
# 9        02       West Ridge
# 10       03           Uptown
# 11       04   Lincoln Square
# 12       09      Edison Park
# 13       10     Norwood Park
# 14       11   Jefferson Park
# 15       12      Forest Glen
# 16       13       North Park
# 17       14      Albany Park
# 18       76           O'Hare
# 19       77        Edgewater
#
#                                         Neighbourhood
# 0   Cabrini–Green ,The Gold Coast ,Goose Island ,M...
# 1      Loop ,New Eastside ,South Loop ,West Loop Gate
# 2   Dearborn Park ,Printer's Row ,South Loop ,Prai...
# 3                         Horner Park ,Roscoe Village
# 4   Boystown ,Lake View East ,Graceland West ,Sout...
# 5   Old Town Triangle ,Park West ,Ranch Triangle ,...
# 6   Belmont Gardens ,Chicago's Polish Village ,Kos...
# 7   Belmont Gardens ,Bucktown ,Kosciuszko Park ,Pa...
# 8                                    East Rogers Park
# 9    Arcadia Terrace ,Peterson Park ,West Rogers Park
# 10  Buena Park ,Argyle Street ,Margate Park ,Sheri...
# 11  Ravenswood ,Ravenswood Gardens ,Rockwell Crossing
# 12                                        Edison Park
# 13  Big Oaks ,Old Norwood Park ,Oriole Park ,Union...
# 14                                     Gladstone Park
# 15  Edgebrook ,Old Edgebrook ,South Edgebrook ,Sau...
# 16  Brynford Park ,Hollywood Park ,River's Edge ,S...
# 17           Mayfair ,North Mayfair ,Ravenswood Manor
# 18                               Schorsch Forest View
# 19  Andersonville ,Edgewater Glen ,Edgewater Beach...

# %%
df_chicagoDistricts.shape
# Out:
# (77, 3)

# %% [markdown]
# <h3>Filter only the major crime data</h3>

# %%
interest_crime_df = crime2015_df[crime2015_df['Primary Type'].str.contains("ARSON|ASSAULT|BATTERY|BURGLARY|TRESPASS|SEX OFFENSE")]
interest_crime_df.shape
# Out:
# (87893, 10)

# %%
crimesData = pd.pivot_table(interest_crime_df,
                               index=['District'],
                               aggfunc=len,fill_value=0)
crimesData.head()
# Out:
#           Arrest  Block  Case Number    ID  Latitude  Location Description  \
# District
# 1           2688   2688         2688  2688      2688                  2688
# 2           3744   3744         3744  3744      3744                  3744
# 3           5377   5377         5377  5377      5377                  5377
# 4           6221   6221         6221  6221      6221                  6221
# 5           4524   4524         4524  4524      4524                  4524
#
#           Longitude  Primary Type  Ward
# District
# 1              2688          2688  2688
# 2              3744          3744  3744
# 3              5377          5377  5377
# 4              6221          6221  6221
# 5              4524          4524  4524

# %%
crimesData.reset_index(inplace = True)
crimesData = crimesData[['District', 'Arrest']]
crimesData.columns = ['District', 'Crime']
crimesData.District.astype(str)
crimesData.head()
# Out:
#    District  Crime
# 0         1   2688
# 1         2   3744
# 2         3   5377
# 3         4   6221
# 4         5   4524

# %% [markdown]
# <h3>Data for total crimes</h3>

# %%
totalCrimes = pd.pivot_table(crime2015_df,
                               index=['District'],
                               aggfunc=len,fill_value=0)

totalCrimes.reset_index(inplace = True)
totalCrimes = totalCrimes[['District', 'Arrest']]
totalCrimes.columns = ['District', 'TotalCrime']
totalCrimes.District.astype(str)
totalCrimes.head()
# Out:
#    District  TotalCrime
# 0         1       11762
# 1         2       10485
# 2         3       12783
# 3         4       15556
# 4         5       11153

# %%
#Now we perform the merge
crimesData = crimesData.merge(totalCrimes, left_on='District', right_on='District')
crimesData.head()
# Out:
#    District  Crime  TotalCrime
# 0         1   2688       11762
# 1         2   3744       10485
# 2         3   5377       12783
# 3         4   6221       15556
# 4         5   4524       11153

# %% [markdown]
# <h3>Calculate the ratio of major crimes and total crimes</h3>

# %%
crimesData['crime_pct'] = crimesData.Crime / crimesData.TotalCrime
crimesData['crime_pct'] = crimesData['crime_pct'].round(4) * 100
crimesData.head()
# Out:
#    District  Crime  TotalCrime  crime_pct
# 0         1   2688       11762      22.85
# 1         2   3744       10485      35.71
# 2         3   5377       12783      42.06
# 3         4   6221       15556      39.99
# 4         5   4524       11153      40.56

# %% [markdown]
# <h3>Merge the crime data and District information</h3>

# %%
#Now we perform the full data merge
crimesData.dtypes
# Out:
# District        int64
# Crime           int64
# TotalCrime      int64
# crime_pct     float64
# dtype: object

# %%
crimesData.dtypes
df_chicagoDistricts['DistCode'] = df_chicagoDistricts['DistCode'].astype(str).astype(int)

# %%
df_chicagoDistricts.dtypes
# Out:
# DistCode          int64
# Community        object
# Neighbourhood    object
# dtype: object

# %%
df_merged = df_chicagoDistricts.merge(crimesData, left_on='DistCode', right_on='District', how='left').drop(['District'], axis=1)

# %%
df_merged['TotalCrime'] = df_merged['TotalCrime'].round()
df_merged['Crime'] = df_merged['Crime'].round()
df_merged['TotalCrime'].fillna(0, inplace=True)
df_merged['Crime'].fillna(0, inplace=True)
df_merged['crime_pct'].fillna(0, inplace=True)

# %%
df_merged.dtypes
# Out:
# DistCode           int64
# Community         object
# Neighbourhood     object
# Crime            float64
# TotalCrime       float64
# crime_pct        float64
# dtype: object

# %%
df_merged['Crime'] = df_merged['Crime'].astype(int)
df_merged['TotalCrime'] = df_merged['TotalCrime'].astype(int)

df_merged
# Out:
#     DistCode           Community  \
# 0          8     Near North Side
# 1         32                Loop
# 2         33     Near South Side
# 3          5        North Center
# 4          6           Lake View
# 5          7        Lincoln Park
# 6         21            Avondale
# 7         22        Logan Square
# 8          1         Rogers Park
# 9          2          West Ridge
# 10         3              Uptown
# 11         4      Lincoln Square
# 12         9         Edison Park
# 13        10        Norwood Park
# 14        11      Jefferson Park
# 15        12         Forest Glen
# 16        13          North Park
# 17        14         Albany Park
# 18        76              O'Hare
# 19        77           Edgewater
# 20        15        Portage Park
# 21        16         Irving Park
# 22        17             Dunning
# 23        18           Montclare
# 24        19      Belmont Cragin
# 25        20             Hermosa
# 26        23       Humboldt Park
# 27        24           West Town
# 28        25              Austin
# 29        26  West Garfield Park
# ..       ...                 ...
# 47        56      Garfield Ridge
# 48        57      Archer Heights
# 49        58       Brighton Park
# 50        59       McKinley Park
# 51        61            New City
# 52        62         West Elsdon
# 53        63           Gage Park
# 54        64            Clearing
# 55        65           West Lawn
# 56        66        Chicago Lawn
# 57        67      West Englewood
# 58        68           Englewood
# 59        44             Chatham
# 60        45         Avalon Park
# 61        46       South Chicago
# 62        47            Burnside
# 63        48     Calumet Heights
# 64        49            Roseland
# 65        50             Pullman
# 66        51       South Deering
# 67        52           East Side
# 68        53        West Pullman
# 69        54           Riverdale
# 70        55           Hegewisch
# 71        70             Ashburn
# 72        71      Auburn Gresham
# 73        72             Beverly
# 74        73  Washington Heights
# 75        74     Mount Greenwood
# 76        75         Morgan Park
#
#                                         Neighbourhood  Crime  TotalCrime  \
# 0   Cabrini–Green ,The Gold Coast ,Goose Island ,M...   5688       16936
# 1      Loop ,New Eastside ,South Loop ,West Loop Gate      0           0
# 2   Dearborn Park ,Printer's Row ,South Loop ,Prai...      0           0
# 3                         Horner Park ,Roscoe Village   4524       11153
# 4   Boystown ,Lake View East ,Graceland West ,Sout...   6146       15767
# 5   Old Town Triangle ,Park West ,Ranch Triangle ,...   5876       15074
# 6   Belmont Gardens ,Chicago's Polish Village ,Kos...      0           0
# 7   Belmont Gardens ,Bucktown ,Kosciuszko Park ,Pa...   2969        8576
# 8                                    East Rogers Park   2688       11762
# 9    Arcadia Terrace ,Peterson Park ,West Rogers Park   3744       10485
# 10  Buena Park ,Argyle Street ,Margate Park ,Sheri...   5377       12783
# 11  Ravenswood ,Ravenswood Gardens ,Rockwell Crossing   6221       15556
# 12                                        Edison Park   4368       12410
# 13  Big Oaks ,Old Norwood Park ,Oriole Park ,Union...   4308       11523
# 14                                     Gladstone Park   5822       18631
# 15  Edgebrook ,Old Edgebrook ,South Edgebrook ,Sau...   3717       12052
# 16  Brynford Park ,Hollywood Park ,River's Edge ,S...      0           0
# 17           Mayfair ,North Mayfair ,Ravenswood Manor   2447        8774
# 18                               Schorsch Forest View      0           0
# 19  Andersonville ,Edgewater Glen ,Edgewater Beach...      0           0
# 20         Belmont Central ,Władysławowo ,Six Corners   4023       11467
# 21  Avondale Gardens ,Independence Park ,Kilbourn ...   3007        9114
# 22  Belmont Heights ,Belmont Terrace ,Irving Woods...   2497        7576
# 23                                          Montclare   2436       11131
# 24                       Belmont Central ,Hanson Park   3221       11327
# 25                       Belmont Gardens ,Kelvyn Park   1355        4167
# 26                                                         0           0
# 27  East Village ,Noble Square ,Polish Downtown ,P...   2415        6873
# 28                               Galewood ,The Island   5043       14747
# 29                                                         0           0
# ..                                                ...    ...         ...
# 47        LeClaire Courts ,Sleepy Hollow ,Vittum Park      0           0
# 48                                                         0           0
# 49                                                         0           0
# 50                                                         0           0
# 51                     Back of the Yards ,Canaryville      0           0
# 52                                                         0           0
# 53                                                         0           0
# 54                                   Chrysler Village      0           0
# 55                               Ford City ,West Lawn      0           0
# 56                   Lithuanian Plaza ,Marquette Park      0           0
# 57                                                         0           0
# 58                                                         0           0
# 59      East Chatham ,West Chatham ,West Chesterfield      0           0
# 60           Avalon Park ,Marynook ,Stony Island Park      0           0
# 61                                           The Bush      0           0
# 62                                                         0           0
# 63                                          Pill Hill      0           0
# 64                                 Fernwood ,Rosemoor      0           0
# 65                Cottage Grove Heights ,London Towne      0           0
# 66                       Jeffrey Manor ,Trumbull Park      0           0
# 67                                                         0           0
# 68                                                         0           0
# 69           Altgeld Gardens ,Eden Green ,Golden Gate      0           0
# 70                                                         0           0
# 71  Beverly View ,Mary Crest ,Parkview ,Scottsdale...      0           0
# 72                                                         0           0
# 73                                                         0           0
# 74           Brainerd ,Longwood Manor ,Princeton Park      0           0
# 75           Mount Greenwood Heights ,Talley's Corner      0           0
# 76      Beverly Woods ,Kennedy Park ,West Morgan Park      0           0
#
#     crime_pct
# 0       33.59
# 1        0.00
# 2        0.00
# 3       40.56
# 4       38.98
# 5       38.98
# 6        0.00
# 7       34.62
# 8       22.85
# 9       35.71
# 10      42.06
# 11      39.99
# 12      35.20
# 13      37.39
# 14      31.25
# 15      30.84
# 16       0.00
# 17      27.89
# 18       0.00
# 19       0.00
# 20      35.08
# 21      32.99
# 22      32.96
# 23      21.88
# 24      28.44
# 25      32.52
# 26       0.00
# 27      35.14
# 28      34.20
# 29       0.00
# ..        ...
# 47       0.00
# 48       0.00
# 49       0.00
# 50       0.00
# 51       0.00
# 52       0.00
# 53       0.00
# 54       0.00
# 55       0.00
# 56       0.00
# 57       0.00
# 58       0.00
# 59       0.00
# 60       0.00
# 61       0.00
# 62       0.00
# 63       0.00
# 64       0.00
# 65       0.00
# 66       0.00
# 67       0.00
# 68       0.00
# 69       0.00
# 70       0.00
# 71       0.00
# 72       0.00
# 73       0.00
# 74       0.00
# 75       0.00
# 76       0.00
#
# [77 rows x 6 columns]

# %%
df_merged.dtypes
# Out:
# DistCode           int64
# Community         object
# Neighbourhood     object
# Crime              int64
# TotalCrime         int64
# crime_pct        float64
# dtype: object

# %%
df_merged.sort_values(by=['crime_pct'])
# Out:
#     DistCode               Community  \
# 38        37             Fuller Park
# 54        64                Clearing
# 53        63               Gage Park
# 52        62             West Elsdon
# 51        61                New City
# 50        59           McKinley Park
# 49        58           Brighton Park
# 48        57          Archer Heights
# 47        56          Garfield Ridge
# 46        69  Greater Grand Crossing
# 45        60              Bridgeport
# 44        43             South Shore
# 43        42                Woodlawn
# 42        41               Hyde Park
# 41        40         Washington Park
# 40        39                 Kenwood
# 55        65               West Lawn
# 56        66            Chicago Lawn
# 57        67          West Englewood
# 58        68               Englewood
# 74        73      Washington Heights
# 73        72                 Beverly
# 72        71          Auburn Gresham
# 71        70                 Ashburn
# 70        55               Hegewisch
# 69        54               Riverdale
# 68        53            West Pullman
# 39        38         Grand Boulevard
# 67        52               East Side
# 65        50                 Pullman
# ..       ...                     ...
# 18        76                  O'Hare
# 31        28          Near West Side
# 29        26      West Garfield Park
# 33        30          South Lawndale
# 35        34           Armour Square
# 32        29          North Lawndale
# 30        27      East Garfield Park
# 34        31         Lower West Side
# 23        18               Montclare
# 8          1             Rogers Park
# 17        14             Albany Park
# 24        19          Belmont Cragin
# 15        12             Forest Glen
# 14        11          Jefferson Park
# 25        20                 Hermosa
# 22        17                 Dunning
# 21        16             Irving Park
# 0          8         Near North Side
# 28        25                  Austin
# 7         22            Logan Square
# 20        15            Portage Park
# 27        24               West Town
# 12         9             Edison Park
# 9          2              West Ridge
# 13        10            Norwood Park
# 5          7            Lincoln Park
# 4          6               Lake View
# 11         4          Lincoln Square
# 3          5            North Center
# 10         3                  Uptown
#
#                                         Neighbourhood  Crime  TotalCrime  \
# 38                                                         0           0
# 54                                   Chrysler Village      0           0
# 53                                                         0           0
# 52                                                         0           0
# 51                     Back of the Yards ,Canaryville      0           0
# 50                                                         0           0
# 49                                                         0           0
# 48                                                         0           0
# 47        LeClaire Courts ,Sleepy Hollow ,Vittum Park      0           0
# 46        Grand Crossing ,Parkway Gardens ,Park Manor      0           0
# 45                                                         0           0
# 44                             Jackson Park Highlands      0           0
# 43                                      West Woodlawn      0           0
# 42                          East Hyde Park ,Hyde Park      0           0
# 41                                                         0           0
# 40                             Kenwood ,South Kenwood      0           0
# 55                               Ford City ,West Lawn      0           0
# 56                   Lithuanian Plaza ,Marquette Park      0           0
# 57                                                         0           0
# 58                                                         0           0
# 74           Brainerd ,Longwood Manor ,Princeton Park      0           0
# 73                                                         0           0
# 72                                                         0           0
# 71  Beverly View ,Mary Crest ,Parkview ,Scottsdale...      0           0
# 70                                                         0           0
# 69           Altgeld Gardens ,Eden Green ,Golden Gate      0           0
# 68                                                         0           0
# 39                                        Bronzeville      0           0
# 67                                                         0           0
# 65                Cottage Grove Heights ,London Towne      0           0
# ..                                                ...    ...         ...
# 18                               Schorsch Forest View      0           0
# 31  Fulton River District ,Fulton Market ,Greektow...      0           0
# 29                                                         0           0
# 33                                     Little Village      0           0
# 35                       Chinatown ,Wentworth Gardens      0           0
# 32               Lawndale ,Homan Square ,Douglas Park      0           0
# 30                                         Fifth City      0           0
# 34  Heart of Chicago ,Heart of Italy ,Pilsen ,East...      1           9
# 23                                          Montclare   2436       11131
# 8                                    East Rogers Park   2688       11762
# 17           Mayfair ,North Mayfair ,Ravenswood Manor   2447        8774
# 24                       Belmont Central ,Hanson Park   3221       11327
# 15  Edgebrook ,Old Edgebrook ,South Edgebrook ,Sau...   3717       12052
# 14                                     Gladstone Park   5822       18631
# 25                       Belmont Gardens ,Kelvyn Park   1355        4167
# 22  Belmont Heights ,Belmont Terrace ,Irving Woods...   2497        7576
# 21  Avondale Gardens ,Independence Park ,Kilbourn ...   3007        9114
# 0   Cabrini–Green ,The Gold Coast ,Goose Island ,M...   5688       16936
# 28                               Galewood ,The Island   5043       14747
# 7   Belmont Gardens ,Bucktown ,Kosciuszko Park ,Pa...   2969        8576
# 20         Belmont Central ,Władysławowo ,Six Corners   4023       11467
# 27  East Village ,Noble Square ,Polish Downtown ,P...   2415        6873
# 12                                        Edison Park   4368       12410
# 9    Arcadia Terrace ,Peterson Park ,West Rogers Park   3744       10485
# 13  Big Oaks ,Old Norwood Park ,Oriole Park ,Union...   4308       11523
# 5   Old Town Triangle ,Park West ,Ranch Triangle ,...   5876       15074
# 4   Boystown ,Lake View East ,Graceland West ,Sout...   6146       15767
# 11  Ravenswood ,Ravenswood Gardens ,Rockwell Crossing   6221       15556
# 3                         Horner Park ,Roscoe Village   4524       11153
# 10  Buena Park ,Argyle Street ,Margate Park ,Sheri...   5377       12783
#
#     crime_pct
# 38       0.00
# 54       0.00
# 53       0.00
# 52       0.00
# 51       0.00
# 50       0.00
# 49       0.00
# 48       0.00
# 47       0.00
# 46       0.00
# 45       0.00
# 44       0.00
# 43       0.00
# 42       0.00
# 41       0.00
# 40       0.00
# 55       0.00
# 56       0.00
# 57       0.00
# 58       0.00
# 74       0.00
# 73       0.00
# 72       0.00
# 71       0.00
# 70       0.00
# 69       0.00
# 68       0.00
# 39       0.00
# 67       0.00
# 65       0.00
# ..        ...
# 18       0.00
# 31       0.00
# 29       0.00
# 33       0.00
# 35       0.00
# 32       0.00
# 30       0.00
# 34      11.11
# 23      21.88
# 8       22.85
# 17      27.89
# 24      28.44
# 15      30.84
# 14      31.25
# 25      32.52
# 22      32.96
# 21      32.99
# 0       33.59
# 28      34.20
# 7       34.62
# 20      35.08
# 27      35.14
# 12      35.20
# 9       35.71
# 13      37.39
# 5       38.98
# 4       38.98
# 11      39.99
# 3       40.56
# 10      42.06
#
# [77 rows x 6 columns]

# %% [markdown]
# <h1>Result and Conclusion</h1>
# From the above tables we have a definite idea of which areas of the city have reported more number of major crimes. The higher the crime numbers the lower is the safety of that neighbourhood.
# This information can be used with differnet perspective.
# For example for a real estate agent this information gives and insight into which places would be highly valued by prospective clients and they can determine the prices and rents accordingly.
# Similarly yhis information can be used by the law enforcement to decide which area needs more focus for increasing security of the populace.
# Finally, this insight brings a migrant to choose the ideal place to set their home.
